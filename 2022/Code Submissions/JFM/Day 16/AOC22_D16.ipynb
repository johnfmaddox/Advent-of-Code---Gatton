# %% [markdown]
# **--- Part One ---**

# %%
## Select input data case
## Note: this assumes a plain textfile named `input_{case}` is located in the same folder as this notebook
case = "example" # <- input_example
case = "jfm"
case = "gatton"

# verbose output
verbose = False

import numpy as np
from itertools import cycle, permutations
import re

regex_pattern = r"Valve \b([A-Z]+)\b.*flow rate=(\d+);.*valves? (.*)$"

# Read input
with open(f'input_{case}','r') as f:
    input_lines = f.readlines()

import numpy as np
import multiprocessing as mp
from tqdm.notebook import tqdm
from functools import lru_cache

class Valve():
    def __init__(self, input_string):
        result = re.search(regex_pattern, input_string)
        self.name = result.groups(1)[0]
        self.rate = int(result.groups(1)[1])
        self.distances = {}
        try:
            self.tunnels = [i.strip() for i in result.groups(1)[2].split(',')]
        except AttributeError:
            self.tunnels = [result.groups(1)[2].strip()]
         
class Volcano():
    def __init__(self, total_minutes=30, part=1, show_progress=False):
        self.score = 0
        self.valves = []
        self.valve_dict = {}
        self.total_minutes = total_minutes
        for line in input_lines:
            valve = Valve(line.strip())
            self.valve_dict[valve.name] = valve
            self.valves.append(valve)
        self.minute = 0
        self.total_flow_rate = 0
        self.closed_valves = [valve.name for valve in self.valves]
        self.open_valves = []
        self.potentials = {}
        self.graph = {valve.name: valve.tunnels for valve in self.valves}
        self.target_valves = [valve.name for valve in self.valves if valve.rate>0]
        self.target_valves.sort(key=lambda x: self.valve_dict[x].rate, reverse=True)
        self.distances = {f'{start},{end}':len(self.shortest_path(start,end))-1 for start in self.target_valves for end in self.target_valves}
        for end in self.target_valves:
            self.distances[f'AA,{end}'] = len(self.shortest_path('AA',end))-1
            self.distances[f'{end},AA'] = self.distances[f'AA,{end}']
        if part == 1:
            self.build_paths()
            self.paths = list(self.paths)
            self.scores = [self.score_path(path) for path in self.paths]
            self.best = max(self.scores)
        elif part == 2:
            print('building paths')
            self.build_2_paths(show_progress=show_progress)
            print('finished building paths')
            self.paths = list(self.paths)
            print('scoring paths')
            self.scores = [self.score_2_paths(path) for path in tqdm(self.paths)]
            self.best = max(self.scores)

    def build_paths(self):
        self.paths = set()
        self.grow_path(['AA'],self.target_valves,32)

    def build_2_paths(self, show_progress=False):
        self.paths = set()
        self.grow_2_paths(['AA'],['AA'],self.target_valves,26,26,show_progress=show_progress)
    
    def grow_path(self, path, others, rem):
        for i,other in enumerate(others):
            new_rem = rem - (self.distances[f'{path[-1]},{other}']+1)
            if new_rem <= 0:
                self.paths.add(tuple(path))
                continue
            new_path = path + [other]
            new_others = others[:i] + others[i+1:]
            if len(new_others):
                self.grow_path(new_path, new_others, new_rem)
            else:
                self.paths.add(tuple(new_path))

    def grow_2_paths(self, path1, path2, others, rem1, rem2, show_progress=False):
        if len(others) == 1:
            others = others + ['AA']

        if (self.potential_score(others,rem1) + self.potential_score(others,rem2))>self.score:
            #return (tuple((path1,path2)))

            target_options = list(permutations(others,2))
            if show_progress:
                prog = lambda x: tqdm(x)
                if not isinstance(show_progress, bool):
                    show_progress -= 1
            else:
                prog = lambda x: x
            for target1,target2 in prog(target_options):

                if rem1>0:
                    new_rem1 = rem1 - (self.distances[f'{path1[-1]},{target1}']+1)
                    if new_rem1>0:
                        new_path1 = path1 + [target1]
                    else:
                        new_path1 = path1
                        new_rem1 = rem1
                else:
                    new_path1 = path1
                    new_rem1 = rem1

                if rem2>0:
                    new_rem2 = rem2 - (self.distances[f'{path2[-1]},{target2}']+1)
                    if new_rem2>0:
                        new_path2 = path2 + [target2]
                    else:
                        new_path2 = path2
                        new_rem2 = rem2              
                else:
                    new_path2 = path2
                    new_rem2 = rem2
                
                new_others = [i for i in others if i not in (target1,target2)]

                if (new_rem1<=0 and new_rem2<=0) or len(new_others)==0:
                    self.score = max([self.score_2_paths([new_path1,new_path2]),self.score])
                    self.paths.add((tuple(new_path1),tuple(new_path2)))
                    continue
                else:
                    self.grow_2_paths(new_path1, new_path2, new_others, new_rem1, new_rem2, show_progress=show_progress)


    def potential_score(self, others, remaining):
        n = int(remaining/2)
        rates = [self.valve_dict[i].rate for i in others]
        rates.sort()
        potential = 0
        for i in range(min(n,len(rates))):
            potential += (remaining-i)*rates[i]
        # print(f'{others=}, {remaining=}, {potential=}')
        return potential
        
    def score_target(self, dest, remaining):
        return remaining*self.valve_dict[dest].rate 
    
    def score_path(self, path, verbose=False):
        # print(path)
        score = 0
        remaining = 30
        per_minute_total = 0
        for i,start in enumerate(path[:-1]):
            end = path[i+1]
            dist = len(self.shortest_path(start, end))-1
            remaining -= dist # move to valve
            remaining -= 1 # open valve
            rate = self.valve_dict[end].rate
            per_minute_total += rate
            valve_score = remaining*rate
            score += valve_score
            if verbose:
                print(f"== Minute {30-remaining} ==")
                print(f'moved {dist} times: opened valve {end}: at {rate} per minute for {remaining} minutes for a total of {per_minute_total} per minute')
            if remaining <=1:
                break
        return score

    def score_2_paths(self, paths, remaining=26, verbose=False):
        # print(path)
        score = 0
        per_minute_total = 0
        for path in paths:
            rem = remaining
            for i,start in enumerate(path[:-1]):
                end = path[i+1]
                dist = len(self.shortest_path(start, end))-1
                rem -= dist # move to valve
                rem -= 1 # open valve
                rate = self.valve_dict[end].rate
                per_minute_total += rate
                valve_score = rem*rate
                score += valve_score
                if verbose:
                    print(f"== Minute {30-rem} ==")
                    print(f'moved {dist} times: opened valve {end}: at {rate} per minute for {remaining} minutes for a total of {per_minute_total} per minute')
                if rem <=1:
                    break
        return score


    @lru_cache(maxsize = None)
    def shortest_path(self, start, dest, max_steps=30):
        path = [start]
        if dest in (tunnels := self.valve_dict[path[-1]].tunnels):
            path.append(dest)
            return path
        paths = []
        for tunnel in tunnels:
            if tunnel not in path:
                new_path = path.copy()#.append(tunnel)
                new_path.append(tunnel)
                paths.append(new_path)
        n = 0
        while n<max_steps:
            new_paths = []
            for path in paths:
                if dest in (tunnels := self.valve_dict[path[-1]].tunnels):
                    path.append(dest)
                    return path
                for tunnel in tunnels:
                    if tunnel not in path:
                        new_path = path.copy()
                        new_path.append(tunnel)
                        new_paths.append(new_path)
            paths = new_paths
            n += 1
        return None

# %%
volcano = Volcano()
print(max(volcano.scores))
# Out:
# 1828

# %%
volcano = Volcano(part=2)
volcano.best
# Out:
# building paths
# finished building paths
# scoring paths
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# 1413

# %%
print(volcano.target_valves)
volcano.paths
# Out:
# ['HH', 'JJ', 'DD', 'BB', 'EE', 'CC']
# [(('AA', 'HH', 'DD', 'JJ'), ('AA', 'EE', 'BB', 'CC')),
#  (('AA', 'JJ', 'HH', 'DD'), ('AA', 'CC', 'EE', 'BB')),
#  (('AA', 'DD', 'HH', 'EE'), ('AA', 'JJ', 'BB', 'CC')),
#  (('AA', 'HH', 'BB', 'EE'), ('AA', 'DD', 'JJ', 'CC')),
#  (('AA', 'CC', 'BB', 'DD'), ('AA', 'HH', 'JJ', 'EE')),
#  (('AA', 'DD', 'CC', 'BB'), ('AA', 'EE', 'HH', 'JJ')),
#  (('AA', 'HH', 'JJ', 'DD'), ('AA', 'EE', 'BB', 'CC')),
#  (('AA', 'DD', 'BB', 'JJ'), ('AA', 'EE', 'CC', 'HH')),
#  (('AA', 'CC', 'DD', 'BB'), ('AA', 'HH', 'JJ', 'EE')),
#  (('AA', 'CC', 'JJ', 'BB'), ('AA', 'EE', 'HH', 'DD')),
#  (('AA', 'CC', 'JJ', 'HH'), ('AA', 'DD', 'BB', 'EE')),
#  (('AA', 'BB', 'CC', 'HH'), ('AA', 'EE', 'JJ', 'DD')),
#  (('AA', 'EE', 'CC', 'HH'), ('AA', 'DD', 'BB', 'JJ')),
#  (('AA', 'EE', 'BB', 'CC'), ('AA', 'HH', 'JJ', 'DD')),
#  (('AA', 'EE', 'CC', 'BB'), ('AA', 'JJ', 'DD', 'HH')),
#  (('AA', 'HH', 'EE', 'CC'), ('AA', 'DD', 'JJ', 'BB')),
#  (('AA', 'CC', 'JJ', 'EE'), ('AA', 'HH', 'DD', 'BB')),
#  (('AA', 'EE', 'BB', 'DD'), ('AA', 'HH', 'CC', 'JJ')),
#  (('AA', 'CC', 'DD', 'HH'), ('AA', 'JJ', 'EE', 'BB')),
#  (('AA', 'JJ', 'CC', 'BB'), ('AA', 'HH', 'DD', 'EE')),
#  (('AA', 'BB', 'HH', 'EE'), ('AA', 'CC', 'JJ', 'DD')),
#  (('AA', 'JJ', 'DD', 'HH'), ('AA', 'CC', 'BB', 'EE')),
#  (('AA', 'HH', 'EE', 'DD'), ('AA', 'CC', 'JJ', 'BB')),
#  (('AA', 'JJ', 'HH', 'EE'), ('AA', 'CC', 'BB', 'DD')),
#  (('AA', 'HH', 'CC', 'BB'), ('AA', 'DD', 'JJ', 'EE')),
#  (('AA', 'DD', 'JJ', 'HH'), ('AA', 'BB', 'EE', 'CC')),
#  (('AA', 'JJ', 'DD', 'HH'), ('AA', 'EE', 'CC', 'BB')),
#  (('AA', 'EE', 'BB', 'JJ'), ('AA', 'CC', 'DD', 'HH')),
#  (('AA', 'EE', 'DD', 'CC'), ('AA', 'JJ', 'BB', 'HH')),
#  (('AA', 'JJ', 'DD', 'CC'), ('AA', 'EE', 'BB', 'HH')),
#  (('AA', 'HH', 'CC', 'EE'), ('AA', 'DD', 'BB', 'JJ')),
#  (('AA', 'JJ', 'BB', 'DD'), ('AA', 'EE', 'CC', 'HH')),
#  (('AA', 'DD', 'EE', 'CC'), ('AA', 'JJ', 'BB', 'HH')),
#  (('AA', 'JJ', 'HH', 'CC'), ('AA', 'BB', 'DD', 'EE')),
#  (('AA', 'DD', 'BB', 'CC'), ('AA', 'HH', 'EE', 'JJ')),
#  (('AA', 'DD', 'BB', 'HH'), ('AA', 'JJ', 'CC', 'EE')),
#  (('AA', 'HH', 'EE', 'DD'), ('AA', 'BB', 'CC', 'JJ')),
#  (('AA', 'EE', 'HH', 'JJ'), ('AA', 'BB', 'CC', 'DD')),
#  (('AA', 'DD', 'JJ', 'BB'), ('AA', 'EE', 'HH', 'CC')),
#  (('AA', 'DD', 'HH', 'CC'), ('AA', 'BB', 'JJ', 'EE')),
#  (('AA', 'HH', 'CC', 'BB'), ('AA', 'DD', 'EE', 'JJ')),
#  (('AA', 'BB', 'HH', 'DD'), ('AA', 'JJ', 'EE', 'CC')),
#  (('AA', 'BB', 'EE', 'JJ'), ('AA', 'CC', 'DD', 'HH')),
#  (('AA', 'JJ', 'BB', 'CC'), ('AA', 'HH', 'EE', 'DD')),
#  (('AA', 'HH', 'CC', 'DD'), ('AA', 'BB', 'JJ', 'EE')),
#  (('AA', 'DD', 'EE', 'BB'), ('AA', 'JJ', 'CC', 'HH')),
#  (('AA', 'BB', 'DD', 'JJ'), ('AA', 'EE', 'HH', 'CC')),
#  (('AA', 'CC', 'BB', 'HH'), ('AA', 'EE', 'DD', 'JJ')),
#  (('AA', 'CC', 'JJ', 'HH'), ('AA', 'BB', 'EE', 'DD')),
#  (('AA', 'DD', 'JJ', 'HH'), ('AA', 'EE', 'CC', 'BB')),
#  (('AA', 'EE', 'BB', 'DD'), ('AA', 'CC', 'JJ', 'HH')),
#  (('AA', 'JJ', 'EE', 'HH'), ('AA', 'DD', 'BB', 'CC')),
#  (('AA', 'JJ', 'CC', 'HH'), ('AA', 'BB', 'DD', 'EE')),
#  (('AA', 'CC', 'HH', 'JJ'), ('AA', 'EE', 'BB', 'DD')),
#  (('AA', 'CC', 'JJ', 'DD'), ('AA', 'HH', 'EE', 'BB')),
#  (('AA', 'HH', 'DD', 'EE'), ('AA', 'JJ', 'CC', 'BB')),
#  (('AA', 'JJ', 'DD', 'CC'), ('AA', 'EE', 'HH', 'BB')),
#  (('AA', 'EE', 'JJ', 'HH'), ('AA', 'CC', 'BB', 'DD')),
#  (('AA', 'CC', 'BB', 'JJ'), ('AA', 'DD', 'HH', 'EE')),
#  (('AA', 'DD', 'JJ', 'CC'), ('AA', 'EE', 'BB', 'HH')),
#  (('AA', 'HH', 'EE', 'BB'), ('AA', 'JJ', 'CC', 'DD')),
#  (('AA', 'BB', 'DD', 'CC'), ('AA', 'HH', 'EE', 'JJ')),
#  (('AA', 'EE', 'HH', 'JJ'), ('AA', 'DD', 'CC', 'BB')),
#  (('AA', 'DD', 'EE', 'JJ'), ('AA', 'HH', 'BB', 'CC')),
#  (('AA', 'CC', 'JJ', 'BB'), ('AA', 'DD', 'HH', 'EE')),
#  (('AA', 'DD', 'HH', 'BB'), ('AA', 'JJ', 'CC', 'EE')),
#  (('AA', 'DD', 'JJ', 'HH'), ('AA', 'BB', 'CC', 'EE')),
#  (('AA', 'JJ', 'EE', 'HH'), ('AA', 'CC', 'DD', 'BB')),
#  (('AA', 'DD', 'CC', 'BB'), ('AA', 'JJ', 'EE', 'HH')),
#  (('AA', 'EE', 'CC', 'JJ'), ('AA', 'DD', 'BB', 'HH')),
#  (('AA', 'DD', 'EE', 'HH'), ('AA', 'CC', 'BB', 'JJ')),
#  (('AA', 'CC', 'DD', 'BB'), ('AA', 'JJ', 'HH', 'EE')),
#  (('AA', 'JJ', 'DD', 'EE'), ('AA', 'HH', 'BB', 'CC')),
#  (('AA', 'CC', 'HH', 'BB'), ('AA', 'JJ', 'EE', 'DD')),
#  (('AA', 'HH', 'JJ', 'CC'), ('AA', 'DD', 'EE', 'BB')),
#  (('AA', 'BB', 'HH', 'JJ'), ('AA', 'CC', 'DD', 'EE')),
#  (('AA', 'BB', 'JJ', 'CC'), ('AA', 'HH', 'DD', 'EE')),
#  (('AA', 'JJ', 'CC', 'DD'), ('AA', 'HH', 'BB', 'EE')),
#  (('AA', 'JJ', 'EE', 'CC'), ('AA', 'DD', 'BB', 'HH')),
#  (('AA', 'HH', 'CC', 'EE'), ('AA', 'DD', 'JJ', 'BB')),
#  (('AA', 'BB', 'HH', 'EE'), ('AA', 'DD', 'JJ', 'CC')),
#  (('AA', 'EE', 'BB', 'DD'), ('AA', 'HH', 'JJ', 'CC')),
#  (('AA', 'CC', 'BB', 'JJ'), ('AA', 'HH', 'DD', 'EE')),
#  (('AA', 'JJ', 'DD', 'BB'), ('AA', 'HH', 'CC', 'EE')),
#  (('AA', 'JJ', 'HH', 'EE'), ('AA', 'DD', 'BB', 'CC')),
#  (('AA', 'DD', 'HH', 'JJ'), ('AA', 'CC', 'EE', 'BB')),
#  (('AA', 'DD', 'BB', 'HH'), ('AA', 'EE', 'CC', 'JJ')),
#  (('AA', 'JJ', 'CC', 'DD'), ('AA', 'BB', 'EE', 'HH')),
#  (('AA', 'EE', 'DD', 'JJ'), ('AA', 'HH', 'BB', 'CC')),
#  (('AA', 'DD', 'CC', 'EE'), ('AA', 'JJ', 'HH', 'BB')),
#  (('AA', 'BB', 'CC', 'JJ'), ('AA', 'EE', 'DD', 'HH')),
#  (('AA', 'HH', 'BB', 'CC'), ('AA', 'JJ', 'EE', 'DD')),
#  (('AA', 'BB', 'EE', 'HH'), ('AA', 'JJ', 'DD', 'CC')),
#  (('AA', 'DD', 'JJ', 'CC'), ('AA', 'EE', 'HH', 'BB')),
#  (('AA', 'EE', 'BB', 'JJ'), ('AA', 'HH', 'CC', 'DD')),
#  (('AA', 'DD', 'CC', 'EE'), ('AA', 'HH', 'BB', 'JJ')),
#  (('AA', 'BB', 'HH', 'CC'), ('AA', 'JJ', 'DD', 'EE')),
#  (('AA', 'BB', 'JJ', 'HH'), ('AA', 'EE', 'DD', 'CC')),
#  (('AA', 'JJ', 'DD', 'EE'), ('AA', 'BB', 'HH', 'CC')),
#  (('AA', 'EE', 'CC', 'JJ'), ('AA', 'DD', 'HH', 'BB')),
#  (('AA', 'CC', 'HH', 'EE'), ('AA', 'BB', 'JJ', 'DD')),
#  (('AA', 'DD', 'HH', 'BB'), ('AA', 'CC', 'JJ', 'EE')),
#  (('AA', 'EE', 'BB', 'HH'), ('AA', 'JJ', 'CC', 'DD')),
#  (('AA', 'JJ', 'CC', 'DD'), ('AA', 'BB', 'HH', 'EE')),
#  (('AA', 'DD', 'HH', 'CC'), ('AA', 'JJ', 'BB', 'EE')),
#  (('AA', 'JJ', 'HH', 'EE'), ('AA', 'CC', 'DD', 'BB')),
#  (('AA', 'CC', 'BB', 'EE'), ('AA', 'DD', 'HH', 'JJ')),
#  (('AA', 'CC', 'HH', 'JJ'), ('AA', 'EE', 'DD', 'BB')),
#  (('AA', 'DD', 'CC', 'HH'), ('AA', 'EE', 'JJ', 'BB')),
#  (('AA', 'HH', 'DD', 'EE'), ('AA', 'JJ', 'BB', 'CC')),
#  (('AA', 'BB', 'EE', 'JJ'), ('AA', 'HH', 'CC', 'DD')),
#  (('AA', 'DD', 'BB', 'JJ'), ('AA', 'HH', 'CC', 'EE')),
#  (('AA', 'CC', 'BB', 'EE'), ('AA', 'HH', 'JJ', 'DD')),
#  (('AA', 'BB', 'DD', 'HH'), ('AA', 'JJ', 'CC', 'EE')),
#  (('AA', 'HH', 'CC', 'DD'), ('AA', 'JJ', 'BB', 'EE')),
#  (('AA', 'BB', 'EE', 'HH'), ('AA', 'CC', 'JJ', 'DD')),
#  (('AA', 'EE', 'DD', 'HH'), ('AA', 'CC', 'BB', 'JJ')),
#  (('AA', 'EE', 'DD', 'JJ'), ('AA', 'BB', 'HH', 'CC')),
#  (('AA', 'DD', 'JJ', 'BB'), ('AA', 'EE', 'CC', 'HH')),
#  (('AA', 'BB', 'CC', 'EE'), ('AA', 'JJ', 'DD', 'HH')),
#  (('AA', 'CC', 'HH', 'DD'), ('AA', 'EE', 'BB', 'JJ')),
#  (('AA', 'CC', 'EE', 'HH'), ('AA', 'JJ', 'BB', 'DD')),
#  (('AA', 'EE', 'BB', 'JJ'), ('AA', 'DD', 'CC', 'HH')),
#  (('AA', 'BB', 'HH', 'EE'), ('AA', 'CC', 'DD', 'JJ')),
#  (('AA', 'HH', 'JJ', 'BB'), ('AA', 'DD', 'CC', 'EE')),
#  (('AA', 'BB', 'HH', 'JJ'), ('AA', 'DD', 'EE', 'CC')),
#  (('AA', 'EE', 'JJ', 'HH'), ('AA', 'DD', 'BB', 'CC')),
#  (('AA', 'DD', 'CC', 'EE'), ('AA', 'BB', 'HH', 'JJ')),
#  (('AA', 'DD', 'HH', 'BB'), ('AA', 'EE', 'CC', 'JJ')),
#  (('AA', 'DD', 'JJ', 'EE'), ('AA', 'HH', 'BB', 'CC')),
#  (('AA', 'DD', 'EE', 'JJ'), ('AA', 'BB', 'CC', 'HH')),
#  (('AA', 'JJ', 'BB', 'DD'), ('AA', 'HH', 'CC', 'EE')),
#  (('AA', 'BB', 'HH', 'CC'), ('AA', 'EE', 'JJ', 'DD')),
#  (('AA', 'DD', 'HH', 'EE'), ('AA', 'CC', 'BB', 'JJ')),
#  (('AA', 'BB', 'DD', 'JJ'), ('AA', 'EE', 'CC', 'HH')),
#  (('AA', 'HH', 'JJ', 'CC'), ('AA', 'DD', 'BB', 'EE')),
#  (('AA', 'BB', 'CC', 'DD'), ('AA', 'HH', 'EE', 'JJ')),
#  (('AA', 'CC', 'JJ', 'DD'), ('AA', 'EE', 'BB', 'HH')),
#  (('AA', 'JJ', 'HH', 'CC'), ('AA', 'EE', 'BB', 'DD')),
#  (('AA', 'DD', 'BB', 'EE'), ('AA', 'JJ', 'CC', 'HH')),
#  (('AA', 'JJ', 'EE', 'HH'), ('AA', 'BB', 'CC', 'DD')),
#  (('AA', 'JJ', 'DD', 'EE'), ('AA', 'BB', 'CC', 'HH')),
#  (('AA', 'BB', 'EE', 'JJ'), ('AA', 'DD', 'CC', 'HH')),
#  (('AA', 'DD', 'EE', 'JJ'), ('AA', 'HH', 'CC', 'BB')),
#  (('AA', 'HH', 'DD', 'CC'), ('AA', 'BB', 'JJ', 'EE')),
#  (('AA', 'HH', 'CC', 'BB'), ('AA', 'JJ', 'EE', 'DD')),
#  (('AA', 'DD', 'CC', 'BB'), ('AA', 'HH', 'JJ', 'EE')),
#  (('AA', 'EE', 'BB', 'JJ'), ('AA', 'CC', 'HH', 'DD')),
#  (('AA', 'CC', 'BB', 'EE'), ('AA', 'DD', 'JJ', 'HH')),
#  (('AA', 'HH', 'BB', 'JJ'), ('AA', 'EE', 'DD', 'CC')),
#  (('AA', 'JJ', 'EE', 'BB'), ('AA', 'CC', 'DD', 'HH')),
#  (('AA', 'JJ', 'DD', 'EE'), ('AA', 'HH', 'CC', 'BB')),
#  (('AA', 'JJ', 'HH', 'BB'), ('AA', 'CC', 'DD', 'EE')),
#  (('AA', 'EE', 'JJ', 'HH'), ('AA', 'CC', 'DD', 'BB')),
#  (('AA', 'HH', 'JJ', 'EE'), ('AA', 'DD', 'CC', 'BB')),
#  (('AA', 'JJ', 'BB', 'CC'), ('AA', 'EE', 'HH', 'DD')),
#  (('AA', 'DD', 'CC', 'HH'), ('AA', 'JJ', 'EE', 'BB')),
#  (('AA', 'EE', 'DD', 'HH'), ('AA', 'JJ', 'CC', 'BB')),
#  (('AA', 'CC', 'DD', 'BB'), ('AA', 'JJ', 'EE', 'HH')),
#  (('AA', 'HH', 'EE', 'CC'), ('AA', 'BB', 'JJ', 'DD')),
#  (('AA', 'EE', 'DD', 'JJ'), ('AA', 'BB', 'CC', 'HH')),
#  (('AA', 'CC', 'EE', 'HH'), ('AA', 'BB', 'DD', 'JJ')),
#  (('AA', 'EE', 'HH', 'CC'), ('AA', 'BB', 'DD', 'JJ')),
#  (('AA', 'BB', 'CC', 'HH'), ('AA', 'DD', 'EE', 'JJ')),
#  (('AA', 'HH', 'CC', 'JJ'), ('AA', 'EE', 'DD', 'BB')),
#  (('AA', 'EE', 'DD', 'BB'), ('AA', 'JJ', 'CC', 'HH')),
#  (('AA', 'CC', 'BB', 'HH'), ('AA', 'JJ', 'DD', 'EE')),
#  (('AA', 'JJ', 'CC', 'HH'), ('AA', 'EE', 'BB', 'DD')),
#  (('AA', 'BB', 'EE', 'JJ'), ('AA', 'CC', 'HH', 'DD')),
#  (('AA', 'EE', 'DD', 'CC'), ('AA', 'BB', 'JJ', 'HH')),
#  (('AA', 'DD', 'BB', 'HH'), ('AA', 'EE', 'JJ', 'CC')),
#  (('AA', 'CC', 'HH', 'JJ'), ('AA', 'BB', 'DD', 'EE')),
#  (('AA', 'EE', 'DD', 'JJ'), ('AA', 'HH', 'CC', 'BB')),
#  (('AA', 'JJ', 'BB', 'EE'), ('AA', 'CC', 'DD', 'HH')),
#  (('AA', 'CC', 'HH', 'BB'), ('AA', 'DD', 'JJ', 'EE')),
#  (('AA', 'BB', 'HH', 'DD'), ('AA', 'CC', 'EE', 'JJ')),
#  (('AA', 'CC', 'JJ', 'DD'), ('AA', 'EE', 'HH', 'BB')),
#  (('AA', 'HH', 'BB', 'DD'), ('AA', 'JJ', 'CC', 'EE')),
#  (('AA', 'HH', 'EE', 'BB'), ('AA', 'JJ', 'DD', 'CC')),
#  (('AA', 'HH', 'DD', 'JJ'), ('AA', 'BB', 'EE', 'CC')),
#  (('AA', 'CC', 'JJ', 'HH'), ('AA', 'DD', 'EE', 'BB')),
#  (('AA', 'DD', 'CC', 'EE'), ('AA', 'HH', 'JJ', 'BB')),
#  (('AA', 'JJ', 'EE', 'HH'), ('AA', 'DD', 'CC', 'BB')),
#  (('AA', 'EE', 'JJ', 'CC'), ('AA', 'BB', 'DD', 'HH')),
#  (('AA', 'JJ', 'HH', 'EE'), ('AA', 'BB', 'CC', 'DD')),
#  (('AA', 'BB', 'CC', 'EE'), ('AA', 'DD', 'HH', 'JJ')),
#  (('AA', 'HH', 'JJ', 'DD'), ('AA', 'BB', 'EE', 'CC')),
#  (('AA', 'HH', 'JJ', 'BB'), ('AA', 'EE', 'DD', 'CC')),
#  (('AA', 'BB', 'DD', 'HH'), ('AA', 'EE', 'CC', 'JJ')),
#  (('AA', 'BB', 'HH', 'JJ'), ('AA', 'DD', 'CC', 'EE')),
#  (('AA', 'CC', 'JJ', 'BB'), ('AA', 'DD', 'EE', 'HH')),
#  (('AA', 'BB', 'CC', 'JJ'), ('AA', 'HH', 'EE', 'DD')),
#  (('AA', 'JJ', 'DD', 'CC'), ('AA', 'HH', 'BB', 'EE')),
#  (('AA', 'BB', 'CC', 'EE'), ('AA', 'HH', 'JJ', 'DD')),
#  (('AA', 'CC', 'HH', 'EE'), ('AA', 'JJ', 'BB', 'DD')),
#  (('AA', 'EE', 'CC', 'JJ'), ('AA', 'HH', 'BB', 'DD')),
#  (('AA', 'HH', 'BB', 'CC'), ('AA', 'DD', 'JJ', 'EE')),
#  (('AA', 'EE', 'JJ', 'BB'), ('AA', 'DD', 'HH', 'CC')),
#  (('AA', 'BB', 'DD', 'EE'), ('AA', 'JJ', 'HH', 'CC')),
#  (('AA', 'CC', 'EE', 'JJ'), ('AA', 'BB', 'DD', 'HH')),
#  (('AA', 'BB', 'EE', 'HH'), ('AA', 'DD', 'JJ', 'CC')),
#  (('AA', 'HH', 'DD', 'BB'), ('AA', 'JJ', 'CC', 'EE')),
#  (('AA', 'HH', 'EE', 'BB'), ('AA', 'CC', 'JJ', 'DD')),
#  (('AA', 'CC', 'BB', 'HH'), ('AA', 'EE', 'JJ', 'DD')),
#  (('AA', 'JJ', 'DD', 'CC'), ('AA', 'BB', 'EE', 'HH')),
#  (('AA', 'JJ', 'HH', 'BB'), ('AA', 'EE', 'CC', 'DD')),
#  (('AA', 'DD', 'JJ', 'EE'), ('AA', 'BB', 'CC', 'HH')),
#  (('AA', 'JJ', 'EE', 'CC'), ('AA', 'HH', 'BB', 'DD')),
#  (('AA', 'JJ', 'HH', 'CC'), ('AA', 'DD', 'BB', 'EE')),
#  (('AA', 'HH', 'DD', 'JJ'), ('AA', 'CC', 'BB', 'EE')),
#  (('AA', 'EE', 'HH', 'BB'), ('AA', 'JJ', 'CC', 'DD')),
#  (('AA', 'JJ', 'CC', 'EE'), ('AA', 'BB', 'DD', 'HH')),
#  (('AA', 'HH', 'DD', 'JJ'), ('AA', 'EE', 'CC', 'BB')),
#  (('AA', 'JJ', 'HH', 'BB'), ('AA', 'DD', 'EE', 'CC')),
#  (('AA', 'JJ', 'CC', 'BB'), ('AA', 'EE', 'DD', 'HH')),
#  (('AA', 'DD', 'JJ', 'EE'), ('AA', 'HH', 'CC', 'BB')),
#  (('AA', 'EE', 'BB', 'JJ'), ('AA', 'HH', 'DD', 'CC')),
#  (('AA', 'HH', 'JJ', 'DD'), ('AA', 'EE', 'CC', 'BB')),
#  (('AA', 'BB', 'JJ', 'DD'), ('AA', 'CC', 'HH', 'EE')),
#  (('AA', 'HH', 'EE', 'JJ'), ('AA', 'CC', 'BB', 'DD')),
#  (('AA', 'DD', 'JJ', 'HH'), ('AA', 'CC', 'EE', 'BB')),
#  (('AA', 'JJ', 'DD', 'CC'), ('AA', 'BB', 'HH', 'EE')),
#  (('AA', 'CC', 'EE', 'DD'), ('AA', 'JJ', 'HH', 'BB')),
#  (('AA', 'JJ', 'HH', 'EE'), ('AA', 'DD', 'CC', 'BB')),
#  (('AA', 'DD', 'CC', 'BB'), ('AA', 'JJ', 'HH', 'EE')),
#  (('AA', 'EE', 'JJ', 'BB'), ('AA', 'HH', 'DD', 'CC')),
#  (('AA', 'JJ', 'DD', 'BB'), ('AA', 'CC', 'EE', 'HH')),
#  (('AA', 'BB', 'CC', 'EE'), ('AA', 'DD', 'JJ', 'HH')),
#  (('AA', 'EE', 'BB', 'HH'), ('AA', 'JJ', 'DD', 'CC')),
#  (('AA', 'CC', 'HH', 'EE'), ('AA', 'BB', 'DD', 'JJ')),
#  (('AA', 'EE', 'JJ', 'HH'), ('AA', 'BB', 'CC', 'DD')),
#  (('AA', 'HH', 'CC', 'JJ'), ('AA', 'BB', 'DD', 'EE')),
#  (('AA', 'CC', 'EE', 'DD'), ('AA', 'HH', 'BB', 'JJ')),
#  (('AA', 'BB', 'JJ', 'EE'), ('AA', 'DD', 'HH', 'CC')),
#  (('AA', 'HH', 'DD', 'CC'), ('AA', 'JJ', 'BB', 'EE')),
#  (('AA', 'DD', 'JJ', 'CC'), ('AA', 'HH', 'BB', 'EE')),
#  (('AA', 'BB', 'EE', 'JJ'), ('AA', 'HH', 'DD', 'CC')),
#  (('AA', 'JJ', 'EE', 'CC'), ('AA', 'BB', 'HH', 'DD')),
#  (('AA', 'HH', 'CC', 'DD'), ('AA', 'BB', 'EE', 'JJ')),
#  (('AA', 'CC', 'BB', 'EE'), ('AA', 'HH', 'DD', 'JJ')),
#  (('AA', 'JJ', 'EE', 'BB'), ('AA', 'HH', 'CC', 'DD')),
#  (('AA', 'BB', 'EE', 'HH'), ('AA', 'CC', 'DD', 'JJ')),
#  (('AA', 'HH', 'JJ', 'BB'), ('AA', 'CC', 'EE', 'DD')),
#  (('AA', 'HH', 'EE', 'DD'), ('AA', 'BB', 'JJ', 'CC')),
#  (('AA', 'BB', 'HH', 'EE'), ('AA', 'DD', 'CC', 'JJ')),
#  (('AA', 'HH', 'JJ', 'DD'), ('AA', 'BB', 'CC', 'EE')),
#  (('AA', 'DD', 'JJ', 'BB'), ('AA', 'HH', 'CC', 'EE')),
#  (('AA', 'JJ', 'HH', 'CC'), ('AA', 'BB', 'EE', 'DD')),
#  (('AA', 'DD', 'EE', 'HH'), ('AA', 'BB', 'CC', 'JJ')),
#  (('AA', 'CC', 'DD', 'EE'), ('AA', 'BB', 'JJ', 'HH')),
#  (('AA', 'HH', 'EE', 'CC'), ('AA', 'JJ', 'BB', 'DD')),
#  (('AA', 'DD', 'JJ', 'CC'), ('AA', 'BB', 'EE', 'HH')),
#  (('AA', 'EE', 'BB', 'HH'), ('AA', 'CC', 'JJ', 'DD')),
#  (('AA', 'EE', 'CC', 'DD'), ('AA', 'BB', 'JJ', 'HH')),
#  (('AA', 'BB', 'DD', 'JJ'), ('AA', 'HH', 'CC', 'EE')),
#  (('AA', 'HH', 'DD', 'EE'), ('AA', 'CC', 'BB', 'JJ')),
#  (('AA', 'JJ', 'BB', 'EE'), ('AA', 'HH', 'CC', 'DD')),
#  (('AA', 'BB', 'JJ', 'EE'), ('AA', 'HH', 'DD', 'CC')),
#  (('AA', 'CC', 'EE', 'DD'), ('AA', 'BB', 'HH', 'JJ')),
#  (('AA', 'BB', 'JJ', 'DD'), ('AA', 'HH', 'CC', 'EE')),
#  (('AA', 'BB', 'EE', 'DD'), ('AA', 'JJ', 'CC', 'HH')),
#  (('AA', 'BB', 'CC', 'EE'), ('AA', 'JJ', 'HH', 'DD')),
#  (('AA', 'EE', 'JJ', 'BB'), ('AA', 'CC', 'DD', 'HH')),
#  (('AA', 'DD', 'JJ', 'CC'), ('AA', 'BB', 'HH', 'EE')),
#  (('AA', 'DD', 'HH', 'CC'), ('AA', 'EE', 'BB', 'JJ')),
#  (('AA', 'JJ', 'EE', 'BB'), ('AA', 'DD', 'CC', 'HH')),
#  (('AA', 'JJ', 'HH', 'BB'), ('AA', 'DD', 'CC', 'EE')),
#  (('AA', 'EE', 'JJ', 'HH'), ('AA', 'DD', 'CC', 'BB')),
#  (('AA', 'BB', 'DD', 'HH'), ('AA', 'EE', 'JJ', 'CC')),
#  (('AA', 'EE', 'DD', 'BB'), ('AA', 'HH', 'CC', 'JJ')),
#  (('AA', 'JJ', 'CC', 'HH'), ('AA', 'BB', 'EE', 'DD')),
#  (('AA', 'HH', 'CC', 'DD'), ('AA', 'EE', 'BB', 'JJ')),
#  (('AA', 'JJ', 'BB', 'DD'), ('AA', 'CC', 'EE', 'HH')),
#  (('AA', 'CC', 'JJ', 'EE'), ('AA', 'BB', 'DD', 'HH')),
#  (('AA', 'JJ', 'DD', 'HH'), ('AA', 'BB', 'CC', 'EE')),
#  (('AA', 'DD', 'BB', 'EE'), ('AA', 'CC', 'JJ', 'HH')),
#  (('AA', 'EE', 'DD', 'HH'), ('AA', 'CC', 'JJ', 'BB')),
#  (('AA', 'HH', 'EE', 'CC'), ('AA', 'BB', 'DD', 'JJ')),
#  (('AA', 'DD', 'EE', 'JJ'), ('AA', 'CC', 'HH', 'BB')),
#  (('AA', 'EE', 'JJ', 'CC'), ('AA', 'BB', 'HH', 'DD')),
#  (('AA', 'JJ', 'DD', 'BB'), ('AA', 'CC', 'HH', 'EE')),
#  (('AA', 'BB', 'HH', 'CC'), ('AA', 'DD', 'JJ', 'EE')),
#  (('AA', 'CC', 'EE', 'HH'), ('AA', 'BB', 'JJ', 'DD')),
#  (('AA', 'EE', 'HH', 'CC'), ('AA', 'BB', 'JJ', 'DD')),
#  (('AA', 'BB', 'JJ', 'CC'), ('AA', 'EE', 'DD', 'HH')),
#  (('AA', 'EE', 'BB', 'DD'), ('AA', 'CC', 'HH', 'JJ')),
#  (('AA', 'DD', 'BB', 'CC'), ('AA', 'EE', 'HH', 'JJ')),
#  (('AA', 'BB', 'CC', 'DD'), ('AA', 'EE', 'JJ', 'HH')),
#  (('AA', 'BB', 'DD', 'EE'), ('AA', 'HH', 'CC', 'JJ')),
#  (('AA', 'JJ', 'BB', 'EE'), ('AA', 'DD', 'CC', 'HH')),
#  (('AA', 'CC', 'HH', 'DD'), ('AA', 'EE', 'JJ', 'BB')),
#  (('AA', 'CC', 'DD', 'JJ'), ('AA', 'HH', 'EE', 'BB')),
#  (('AA', 'BB', 'CC', 'HH'), ('AA', 'JJ', 'EE', 'DD')),
#  (('AA', 'JJ', 'DD', 'EE'), ('AA', 'CC', 'HH', 'BB')),
#  (('AA', 'DD', 'EE', 'BB'), ('AA', 'JJ', 'HH', 'CC')),
#  (('AA', 'CC', 'HH', 'EE'), ('AA', 'JJ', 'DD', 'BB')),
#  (('AA', 'JJ', 'EE', 'BB'), ('AA', 'CC', 'HH', 'DD')),
#  (('AA', 'CC', 'BB', 'JJ'), ('AA', 'EE', 'DD', 'HH')),
#  (('AA', 'EE', 'DD', 'HH'), ('AA', 'BB', 'CC', 'JJ')),
#  (('AA', 'CC', 'HH', 'JJ'), ('AA', 'DD', 'EE', 'BB')),
#  (('AA', 'HH', 'EE', 'JJ'), ('AA', 'DD', 'BB', 'CC')),
#  (('AA', 'CC', 'EE', 'JJ'), ('AA', 'BB', 'HH', 'DD')),
#  (('AA', 'DD', 'HH', 'EE'), ('AA', 'CC', 'JJ', 'BB')),
#  (('AA', 'BB', 'HH', 'JJ'), ('AA', 'CC', 'EE', 'DD')),
#  (('AA', 'HH', 'BB', 'EE'), ('AA', 'JJ', 'CC', 'DD')),
#  (('AA', 'BB', 'HH', 'CC'), ('AA', 'DD', 'EE', 'JJ')),
#  (('AA', 'BB', 'JJ', 'EE'), ('AA', 'CC', 'DD', 'HH')),
#  (('AA', 'EE', 'CC', 'BB'), ('AA', 'DD', 'HH', 'JJ')),
#  (('AA', 'DD', 'BB', 'HH'), ('AA', 'CC', 'JJ', 'EE')),
#  (('AA', 'EE', 'CC', 'HH'), ('AA', 'DD', 'JJ', 'BB')),
#  (('AA', 'EE', 'DD', 'BB'), ('AA', 'CC', 'JJ', 'HH')),
#  (('AA', 'EE', 'DD', 'JJ'), ('AA', 'CC', 'HH', 'BB')),
#  (('AA', 'CC', 'EE', 'DD'), ('AA', 'HH', 'JJ', 'BB')),
#  (('AA', 'JJ', 'CC', 'EE'), ('AA', 'BB', 'HH', 'DD')),
#  (('AA', 'DD', 'HH', 'EE'), ('AA', 'BB', 'CC', 'JJ')),
#  (('AA', 'BB', 'CC', 'EE'), ('AA', 'HH', 'DD', 'JJ')),
#  (('AA', 'EE', 'CC', 'BB'), ('AA', 'HH', 'JJ', 'DD')),
#  (('AA', 'BB', 'CC', 'JJ'), ('AA', 'EE', 'HH', 'DD')),
#  (('AA', 'JJ', 'BB', 'EE'), ('AA', 'CC', 'HH', 'DD')),
#  (('AA', 'JJ', 'CC', 'BB'), ('AA', 'HH', 'EE', 'DD')),
#  (('AA', 'DD', 'BB', 'JJ'), ('AA', 'CC', 'HH', 'EE')),
#  (('AA', 'CC', 'EE', 'BB'), ('AA', 'JJ', 'DD', 'HH')),
#  (('AA', 'HH', 'EE', 'JJ'), ('AA', 'CC', 'DD', 'BB')),
#  (('AA', 'EE', 'HH', 'DD'), ('AA', 'JJ', 'BB', 'CC')),
#  (('AA', 'DD', 'BB', 'EE'), ('AA', 'HH', 'JJ', 'CC')),
#  (('AA', 'HH', 'EE', 'BB'), ('AA', 'CC', 'DD', 'JJ')),
#  (('AA', 'BB', 'DD', 'EE'), ('AA', 'CC', 'JJ', 'HH')),
#  (('AA', 'JJ', 'BB', 'HH'), ('AA', 'EE', 'CC', 'DD')),
#  (('AA', 'EE', 'HH', 'BB'), ('AA', 'JJ', 'DD', 'CC')),
#  (('AA', 'CC', 'JJ', 'DD'), ('AA', 'BB', 'EE', 'HH')),
#  (('AA', 'CC', 'DD', 'HH'), ('AA', 'BB', 'JJ', 'EE')),
#  (('AA', 'EE', 'BB', 'HH'), ('AA', 'DD', 'JJ', 'CC')),
#  (('AA', 'JJ', 'EE', 'BB'), ('AA', 'DD', 'HH', 'CC')),
#  (('AA', 'CC', 'HH', 'DD'), ('AA', 'BB', 'EE', 'JJ')),
#  (('AA', 'BB', 'DD', 'CC'), ('AA', 'EE', 'HH', 'JJ')),
#  (('AA', 'HH', 'BB', 'DD'), ('AA', 'EE', 'JJ', 'CC')),
#  (('AA', 'CC', 'DD', 'EE'), ('AA', 'JJ', 'BB', 'HH')),
#  (('AA', 'JJ', 'BB', 'HH'), ('AA', 'DD', 'EE', 'CC')),
#  (('AA', 'BB', 'EE', 'CC'), ('AA', 'JJ', 'DD', 'HH')),
#  (('AA', 'JJ', 'HH', 'DD'), ('AA', 'CC', 'BB', 'EE')),
#  (('AA', 'JJ', 'BB', 'DD'), ('AA', 'CC', 'HH', 'EE')),
#  (('AA', 'EE', 'HH', 'DD'), ('AA', 'BB', 'JJ', 'CC')),
#  (('AA', 'CC', 'JJ', 'BB'), ('AA', 'HH', 'DD', 'EE')),
#  (('AA', 'EE', 'JJ', 'DD'), ('AA', 'CC', 'BB', 'HH')),
#  (('AA', 'DD', 'EE', 'CC'), ('AA', 'JJ', 'HH', 'BB')),
#  (('AA', 'EE', 'CC', 'DD'), ('AA', 'JJ', 'BB', 'HH')),
#  (('AA', 'CC', 'BB', 'DD'), ('AA', 'HH', 'EE', 'JJ')),
#  (('AA', 'EE', 'DD', 'CC'), ('AA', 'HH', 'BB', 'JJ')),
#  (('AA', 'CC', 'DD', 'BB'), ('AA', 'HH', 'EE', 'JJ')),
#  (('AA', 'CC', 'JJ', 'DD'), ('AA', 'BB', 'HH', 'EE')),
#  (('AA', 'JJ', 'BB', 'EE'), ('AA', 'DD', 'HH', 'CC')),
#  (('AA', 'HH', 'EE', 'CC'), ('AA', 'JJ', 'DD', 'BB')),
#  (('AA', 'JJ', 'BB', 'CC'), ('AA', 'DD', 'EE', 'HH')),
#  (('AA', 'EE', 'CC', 'BB'), ('AA', 'DD', 'JJ', 'HH')),
#  (('AA', 'DD', 'EE', 'CC'), ('AA', 'HH', 'BB', 'JJ')),
#  (('AA', 'EE', 'HH', 'BB'), ('AA', 'CC', 'JJ', 'DD')),
#  (('AA', 'EE', 'JJ', 'BB'), ('AA', 'HH', 'CC', 'DD')),
#  (('AA', 'HH', 'CC', 'JJ'), ('AA', 'EE', 'BB', 'DD')),
#  (('AA', 'EE', 'DD', 'BB'), ('AA', 'HH', 'JJ', 'CC')),
#  (('AA', 'DD', 'JJ', 'EE'), ('AA', 'CC', 'HH', 'BB')),
#  (('AA', 'HH', 'DD', 'BB'), ('AA', 'EE', 'JJ', 'CC')),
#  (('AA', 'BB', 'EE', 'HH'), ('AA', 'DD', 'CC', 'JJ')),
#  (('AA', 'HH', 'CC', 'EE'), ('AA', 'BB', 'DD', 'JJ')),
#  (('AA', 'JJ', 'EE', 'BB'), ('AA', 'HH', 'DD', 'CC')),
#  (('AA', 'HH', 'JJ', 'EE'), ('AA', 'BB', 'DD', 'CC')),
#  (('AA', 'JJ', 'EE', 'CC'), ('AA', 'DD', 'HH', 'BB')),
#  (('AA', 'CC', 'HH', 'JJ'), ('AA', 'DD', 'BB', 'EE')),
#  (('AA', 'JJ', 'HH', 'DD'), ('AA', 'EE', 'BB', 'CC')),
#  (('AA', 'DD', 'BB', 'HH'), ('AA', 'JJ', 'EE', 'CC')),
#  (('AA', 'BB', 'JJ', 'DD'), ('AA', 'HH', 'EE', 'CC')),
#  (('AA', 'BB', 'DD', 'EE'), ('AA', 'HH', 'JJ', 'CC')),
#  (('AA', 'EE', 'JJ', 'CC'), ('AA', 'DD', 'BB', 'HH')),
#  (('AA', 'CC', 'BB', 'HH'), ('AA', 'DD', 'EE', 'JJ')),
#  (('AA', 'EE', 'HH', 'CC'), ('AA', 'JJ', 'BB', 'DD')),
#  (('AA', 'EE', 'BB', 'HH'), ('AA', 'CC', 'DD', 'JJ')),
#  (('AA', 'CC', 'DD', 'JJ'), ('AA', 'EE', 'BB', 'HH')),
#  (('AA', 'EE', 'CC', 'JJ'), ('AA', 'HH', 'DD', 'BB')),
#  (('AA', 'JJ', 'BB', 'EE'), ('AA', 'HH', 'DD', 'CC')),
#  (('AA', 'EE', 'DD', 'CC'), ('AA', 'BB', 'HH', 'JJ')),
#  (('AA', 'EE', 'JJ', 'BB'), ('AA', 'DD', 'CC', 'HH')),
#  (('AA', 'DD', 'EE', 'CC'), ('AA', 'BB', 'HH', 'JJ')),
#  (('AA', 'JJ', 'HH', 'BB'), ('AA', 'CC', 'EE', 'DD')),
#  (('AA', 'CC', 'EE', 'JJ'), ('AA', 'DD', 'BB', 'HH')),
#  (('AA', 'JJ', 'EE', 'HH'), ('AA', 'BB', 'DD', 'CC')),
#  (('AA', 'JJ', 'HH', 'CC'), ('AA', 'DD', 'EE', 'BB')),
#  (('AA', 'DD', 'EE', 'BB'), ('AA', 'HH', 'CC', 'JJ')),
#  (('AA', 'DD', 'JJ', 'BB'), ('AA', 'CC', 'EE', 'HH')),
#  (('AA', 'BB', 'JJ', 'CC'), ('AA', 'HH', 'EE', 'DD')),
#  (('AA', 'EE', 'CC', 'BB'), ('AA', 'JJ', 'HH', 'DD')),
#  (('AA', 'BB', 'JJ', 'EE'), ('AA', 'HH', 'CC', 'DD')),
#  (('AA', 'JJ', 'EE', 'CC'), ('AA', 'HH', 'DD', 'BB')),
#  (('AA', 'CC', 'HH', 'BB'), ('AA', 'EE', 'DD', 'JJ')),
#  (('AA', 'HH', 'DD', 'CC'), ('AA', 'EE', 'BB', 'JJ')),
#  (('AA', 'BB', 'CC', 'DD'), ('AA', 'JJ', 'HH', 'EE')),
#  (('AA', 'BB', 'CC', 'HH'), ('AA', 'DD', 'JJ', 'EE')),
#  (('AA', 'BB', 'EE', 'CC'), ('AA', 'DD', 'HH', 'JJ')),
#  (('AA', 'CC', 'BB', 'JJ'), ('AA', 'HH', 'EE', 'DD')),
#  (('AA', 'HH', 'EE', 'JJ'), ('AA', 'BB', 'CC', 'DD')),
#  (('AA', 'HH', 'JJ', 'DD'), ('AA', 'CC', 'EE', 'BB')),
#  (('AA', 'JJ', 'CC', 'EE'), ('AA', 'DD', 'BB', 'HH')),
#  (('AA', 'DD', 'BB', 'EE'), ('AA', 'JJ', 'HH', 'CC')),
#  (('AA', 'BB', 'DD', 'JJ'), ('AA', 'CC', 'EE', 'HH')),
#  (('AA', 'CC', 'HH', 'JJ'), ('AA', 'BB', 'EE', 'DD')),
#  (('AA', 'BB', 'JJ', 'DD'), ('AA', 'CC', 'EE', 'HH')),
#  (('AA', 'BB', 'DD', 'HH'), ('AA', 'CC', 'JJ', 'EE')),
#  (('AA', 'EE', 'JJ', 'BB'), ('AA', 'CC', 'HH', 'DD')),
#  (('AA', 'EE', 'JJ', 'CC'), ('AA', 'DD', 'HH', 'BB')),
#  (('AA', 'BB', 'CC', 'DD'), ('AA', 'EE', 'HH', 'JJ')),
#  (('AA', 'BB', 'EE', 'DD'), ('AA', 'CC', 'JJ', 'HH')),
#  (('AA', 'HH', 'BB', 'CC'), ('AA', 'EE', 'DD', 'JJ')),
#  (('AA', 'DD', 'HH', 'BB'), ('AA', 'JJ', 'EE', 'CC')),
#  (('AA', 'HH', 'EE', 'DD'), ('AA', 'JJ', 'CC', 'BB')),
#  (('AA', 'DD', 'BB', 'CC'), ('AA', 'EE', 'JJ', 'HH')),
#  (('AA', 'CC', 'DD', 'HH'), ('AA', 'JJ', 'BB', 'EE')),
#  (('AA', 'CC', 'DD', 'JJ'), ('AA', 'EE', 'HH', 'BB')),
#  (('AA', 'CC', 'HH', 'EE'), ('AA', 'DD', 'BB', 'JJ')),
#  (('AA', 'HH', 'JJ', 'CC'), ('AA', 'EE', 'DD', 'BB')),
#  (('AA', 'JJ', 'CC', 'HH'), ('AA', 'DD', 'EE', 'BB')),
#  (('AA', 'BB', 'JJ', 'EE'), ('AA', 'DD', 'CC', 'HH')),
#  (('AA', 'HH', 'BB', 'EE'), ('AA', 'JJ', 'DD', 'CC')),
#  (('AA', 'CC', 'EE', 'JJ'), ('AA', 'DD', 'HH', 'BB')),
#  (('AA', 'DD', 'EE', 'BB'), ('AA', 'CC', 'JJ', 'HH')),
#  (('AA', 'HH', 'DD', 'EE'), ('AA', 'CC', 'JJ', 'BB')),
#  (('AA', 'EE', 'DD', 'BB'), ('AA', 'JJ', 'HH', 'CC')),
#  (('AA', 'BB', 'HH', 'CC'), ('AA', 'JJ', 'EE', 'DD')),
#  (('AA', 'EE', 'BB', 'DD'), ('AA', 'JJ', 'CC', 'HH')),
#  (('AA', 'EE', 'HH', 'BB'), ('AA', 'DD', 'JJ', 'CC')),
#  (('AA', 'DD', 'HH', 'CC'), ('AA', 'EE', 'JJ', 'BB')),
#  (('AA', 'DD', 'EE', 'CC'), ('AA', 'HH', 'JJ', 'BB')),
#  (('AA', 'JJ', 'DD', 'BB'), ('AA', 'HH', 'EE', 'CC')),
#  (('AA', 'JJ', 'EE', 'DD'), ('AA', 'CC', 'BB', 'HH')),
#  (('AA', 'JJ', 'CC', 'EE'), ('AA', 'DD', 'HH', 'BB')),
#  (('AA', 'JJ', 'DD', 'HH'), ('AA', 'CC', 'EE', 'BB')),
#  (('AA', 'HH', 'DD', 'EE'), ('AA', 'BB', 'CC', 'JJ')),
#  (('AA', 'HH', 'EE', 'JJ'), ('AA', 'DD', 'CC', 'BB')),
#  (('AA', 'BB', 'EE', 'CC'), ('AA', 'DD', 'JJ', 'HH')),
#  (('AA', 'EE', 'CC', 'BB'), ('AA', 'HH', 'DD', 'JJ')),
#  (('AA', 'HH', 'EE', 'BB'), ('AA', 'DD', 'CC', 'JJ')),
#  (('AA', 'HH', 'CC', 'DD'), ('AA', 'EE', 'JJ', 'BB')),
#  (('AA', 'JJ', 'CC', 'BB'), ('AA', 'EE', 'HH', 'DD')),
#  (('AA', 'DD', 'CC', 'JJ'), ('AA', 'HH', 'EE', 'BB')),
#  (('AA', 'BB', 'JJ', 'EE'), ('AA', 'CC', 'HH', 'DD')),
#  (('AA', 'DD', 'JJ', 'BB'), ('AA', 'CC', 'HH', 'EE')),
#  (('AA', 'HH', 'BB', 'EE'), ('AA', 'CC', 'JJ', 'DD')),
#  (('AA', 'EE', 'JJ', 'DD'), ('AA', 'HH', 'BB', 'CC')),
#  (('AA', 'DD', 'EE', 'HH'), ('AA', 'JJ', 'BB', 'CC')),
#  (('AA', 'DD', 'CC', 'EE'), ('AA', 'BB', 'JJ', 'HH')),
#  (('AA', 'BB', 'DD', 'CC'), ('AA', 'EE', 'JJ', 'HH')),
#  (('AA', 'BB', 'DD', 'JJ'), ('AA', 'CC', 'HH', 'EE')),
#  (('AA', 'HH', 'CC', 'JJ'), ('AA', 'BB', 'EE', 'DD')),
#  (('AA', 'BB', 'HH', 'DD'), ('AA', 'JJ', 'CC', 'EE')),
#  (('AA', 'DD', 'HH', 'JJ'), ('AA', 'EE', 'BB', 'CC')),
#  (('AA', 'BB', 'JJ', 'HH'), ('AA', 'CC', 'DD', 'EE')),
#  (('AA', 'DD', 'BB', 'JJ'), ('AA', 'HH', 'EE', 'CC')),
#  (('AA', 'EE', 'CC', 'DD'), ('AA', 'BB', 'HH', 'JJ')),
#  (('AA', 'DD', 'EE', 'BB'), ('AA', 'HH', 'JJ', 'CC')),
#  (('AA', 'BB', 'DD', 'HH'), ('AA', 'JJ', 'EE', 'CC')),
#  (('AA', 'HH', 'BB', 'DD'), ('AA', 'CC', 'JJ', 'EE')),
#  (('AA', 'EE', 'BB', 'CC'), ('AA', 'JJ', 'DD', 'HH')),
#  (('AA', 'EE', 'CC', 'HH'), ('AA', 'BB', 'JJ', 'DD')),
#  (('AA', 'DD', 'EE', 'HH'), ('AA', 'BB', 'JJ', 'CC')),
#  (('AA', 'HH', 'CC', 'BB'), ('AA', 'EE', 'DD', 'JJ')),
#  (('AA', 'JJ', 'BB', 'CC'), ('AA', 'DD', 'HH', 'EE')),
#  (('AA', 'EE', 'HH', 'DD'), ('AA', 'CC', 'BB', 'JJ')),
#  (('AA', 'HH', 'JJ', 'EE'), ('AA', 'CC', 'BB', 'DD')),
#  (('AA', 'HH', 'EE', 'CC'), ('AA', 'DD', 'BB', 'JJ')),
#  (('AA', 'DD', 'HH', 'CC'), ('AA', 'BB', 'EE', 'JJ')),
#  (('AA', 'HH', 'EE', 'DD'), ('AA', 'JJ', 'BB', 'CC')),
#  (('AA', 'EE', 'HH', 'BB'), ('AA', 'CC', 'DD', 'JJ')),
#  (('AA', 'CC', 'EE', 'HH'), ('AA', 'JJ', 'DD', 'BB')),
#  (('AA', 'BB', 'EE', 'CC'), ('AA', 'JJ', 'HH', 'DD')),
#  (('AA', 'EE', 'HH', 'CC'), ('AA', 'JJ', 'DD', 'BB')),
#  (('AA', 'DD', 'HH', 'CC'), ('AA', 'JJ', 'EE', 'BB')),
#  (('AA', 'CC', 'HH', 'EE'), ('AA', 'DD', 'JJ', 'BB')),
#  (('AA', 'EE', 'JJ', 'DD'), ('AA', 'BB', 'HH', 'CC')),
#  (('AA', 'BB', 'CC', 'DD'), ('AA', 'JJ', 'EE', 'HH')),
#  (('AA', 'HH', 'JJ', 'CC'), ('AA', 'BB', 'DD', 'EE')),
#  (('AA', 'DD', 'CC', 'HH'), ('AA', 'BB', 'JJ', 'EE')),
#  (('AA', 'HH', 'CC', 'EE'), ('AA', 'BB', 'JJ', 'DD')),
#  (('AA', 'JJ', 'CC', 'HH'), ('AA', 'DD', 'BB', 'EE')),
#  (('AA', 'HH', 'DD', 'JJ'), ('AA', 'BB', 'CC', 'EE')),
#  (('AA', 'JJ', 'BB', 'DD'), ('AA', 'HH', 'EE', 'CC')),
#  (('AA', 'HH', 'CC', 'DD'), ('AA', 'JJ', 'EE', 'BB')),
#  (('AA', 'BB', 'DD', 'CC'), ('AA', 'HH', 'JJ', 'EE')),
#  (('AA', 'EE', 'BB', 'HH'), ('AA', 'DD', 'CC', 'JJ')),
#  (('AA', 'DD', 'EE', 'JJ'), ('AA', 'CC', 'BB', 'HH')),
#  (('AA', 'HH', 'DD', 'BB'), ('AA', 'CC', 'JJ', 'EE')),
#  (('AA', 'DD', 'BB', 'EE'), ('AA', 'HH', 'CC', 'JJ')),
#  (('AA', 'BB', 'HH', 'JJ'), ('AA', 'EE', 'DD', 'CC')),
#  (('AA', 'HH', 'BB', 'DD'), ('AA', 'EE', 'CC', 'JJ')),
#  (('AA', 'CC', 'BB', 'DD'), ('AA', 'EE', 'JJ', 'HH')),
#  (('AA', 'JJ', 'EE', 'HH'), ('AA', 'CC', 'BB', 'DD')),
#  (('AA', 'CC', 'BB', 'HH'), ('AA', 'JJ', 'EE', 'DD')),
#  (('AA', 'EE', 'JJ', 'CC'), ('AA', 'HH', 'BB', 'DD')),
#  (('AA', 'CC', 'DD', 'BB'), ('AA', 'EE', 'JJ', 'HH')),
#  (('AA', 'JJ', 'BB', 'CC'), ('AA', 'HH', 'DD', 'EE')),
#  (('AA', 'DD', 'CC', 'BB'), ('AA', 'HH', 'EE', 'JJ')),
#  (('AA', 'BB', 'HH', 'DD'), ('AA', 'CC', 'JJ', 'EE')),
#  (('AA', 'DD', 'BB', 'JJ'), ('AA', 'CC', 'EE', 'HH')),
#  (('AA', 'EE', 'HH', 'DD'), ('AA', 'JJ', 'CC', 'BB')),
#  (('AA', 'BB', 'CC', 'JJ'), ('AA', 'DD', 'EE', 'HH')),
#  (('AA', 'BB', 'JJ', 'CC'), ('AA', 'EE', 'HH', 'DD')),
#  (('AA', 'BB', 'JJ', 'HH'), ('AA', 'EE', 'CC', 'DD')),
#  (('AA', 'EE', 'HH', 'JJ'), ('AA', 'BB', 'DD', 'CC')),
#  (('AA', 'CC', 'EE', 'JJ'), ('AA', 'HH', 'BB', 'DD')),
#  (('AA', 'DD', 'BB', 'HH'), ('AA', 'CC', 'EE', 'JJ')),
#  (('AA', 'HH', 'BB', 'JJ'), ('AA', 'CC', 'DD', 'EE')),
#  (('AA', 'HH', 'DD', 'BB'), ('AA', 'EE', 'CC', 'JJ')),
#  (('AA', 'DD', 'BB', 'CC'), ('AA', 'JJ', 'HH', 'EE')),
#  (('AA', 'BB', 'JJ', 'HH'), ('AA', 'DD', 'EE', 'CC')),
#  (('AA', 'EE', 'JJ', 'DD'), ('AA', 'BB', 'CC', 'HH')),
#  (('AA', 'CC', 'BB', 'JJ'), ('AA', 'EE', 'HH', 'DD')),
#  (('AA', 'CC', 'HH', 'BB'), ('AA', 'JJ', 'DD', 'EE')),
#  (('AA', 'CC', 'JJ', 'HH'), ('AA', 'EE', 'DD', 'BB')),
#  (('AA', 'JJ', 'BB', 'HH'), ('AA', 'CC', 'DD', 'EE')),
#  (('AA', 'BB', 'EE', 'CC'), ('AA', 'HH', 'DD', 'JJ')),
#  (('AA', 'HH', 'BB', 'DD'), ('AA', 'JJ', 'EE', 'CC')),
#  (('AA', 'BB', 'EE', 'DD'), ('AA', 'JJ', 'HH', 'CC')),
#  (('AA', 'HH', 'EE', 'BB'), ('AA', 'DD', 'JJ', 'CC')),
#  (('AA', 'JJ', 'CC', 'EE'), ('AA', 'HH', 'BB', 'DD')),
#  (('AA', 'EE', 'BB', 'CC'), ('AA', 'DD', 'HH', 'JJ')),
#  (('AA', 'BB', 'HH', 'DD'), ('AA', 'EE', 'CC', 'JJ')),
#  (('AA', 'DD', 'BB', 'EE'), ('AA', 'CC', 'HH', 'JJ')),
#  (('AA', 'DD', 'CC', 'JJ'), ('AA', 'EE', 'BB', 'HH')),
#  (('AA', 'EE', 'JJ', 'DD'), ('AA', 'HH', 'CC', 'BB')),
#  (('AA', 'CC', 'DD', 'HH'), ('AA', 'BB', 'EE', 'JJ')),
#  (('AA', 'DD', 'HH', 'EE'), ('AA', 'BB', 'JJ', 'CC')),
#  (('AA', 'JJ', 'EE', 'DD'), ('AA', 'HH', 'BB', 'CC')),
#  (('AA', 'HH', 'BB', 'CC'), ('AA', 'JJ', 'DD', 'EE')),
#  (('AA', 'DD', 'CC', 'EE'), ('AA', 'JJ', 'BB', 'HH')),
#  (('AA', 'HH', 'JJ', 'BB'), ('AA', 'CC', 'DD', 'EE')),
#  (('AA', 'HH', 'DD', 'BB'), ('AA', 'JJ', 'EE', 'CC')),
#  (('AA', 'HH', 'JJ', 'EE'), ('AA', 'DD', 'BB', 'CC')),
#  (('AA', 'CC', 'JJ', 'BB'), ('AA', 'EE', 'DD', 'HH')),
#  (('AA', 'EE', 'CC', 'HH'), ('AA', 'JJ', 'BB', 'DD')),
#  (('AA', 'JJ', 'HH', 'DD'), ('AA', 'BB', 'EE', 'CC')),
#  (('AA', 'CC', 'DD', 'JJ'), ('AA', 'HH', 'BB', 'EE')),
#  (('AA', 'HH', 'DD', 'CC'), ('AA', 'EE', 'JJ', 'BB')),
#  (('AA', 'EE', 'DD', 'BB'), ('AA', 'CC', 'HH', 'JJ')),
#  (('AA', 'CC', 'HH', 'BB'), ('AA', 'EE', 'JJ', 'DD')),
#  (('AA', 'DD', 'HH', 'BB'), ('AA', 'CC', 'EE', 'JJ')),
#  (('AA', 'DD', 'JJ', 'EE'), ('AA', 'CC', 'BB', 'HH')),
#  (('AA', 'CC', 'JJ', 'DD'), ('AA', 'HH', 'BB', 'EE')),
#  (('AA', 'BB', 'DD', 'CC'), ('AA', 'JJ', 'HH', 'EE')),
#  (('AA', 'HH', 'BB', 'JJ'), ('AA', 'EE', 'CC', 'DD')),
#  (('AA', 'BB', 'CC', 'DD'), ('AA', 'HH', 'JJ', 'EE')),
#  (('AA', 'JJ', 'DD', 'HH'), ('AA', 'EE', 'BB', 'CC')),
#  (('AA', 'CC', 'DD', 'JJ'), ('AA', 'BB', 'EE', 'HH')),
#  (('AA', 'DD', 'JJ', 'HH'), ('AA', 'CC', 'BB', 'EE')),
#  (('AA', 'DD', 'CC', 'HH'), ('AA', 'JJ', 'BB', 'EE')),
#  (('AA', 'HH', 'CC', 'EE'), ('AA', 'JJ', 'BB', 'DD')),
#  (('AA', 'HH', 'BB', 'EE'), ('AA', 'CC', 'DD', 'JJ')),
#  (('AA', 'DD', 'CC', 'JJ'), ('AA', 'EE', 'HH', 'BB')),
#  (('AA', 'EE', 'BB', 'CC'), ('AA', 'DD', 'JJ', 'HH')),
#  (('AA', 'HH', 'BB', 'JJ'), ('AA', 'DD', 'EE', 'CC')),
#  (('AA', 'BB', 'DD', 'EE'), ('AA', 'CC', 'HH', 'JJ')),
#  (('AA', 'CC', 'DD', 'HH'), ('AA', 'EE', 'BB', 'JJ')),
#  (('AA', 'JJ', 'EE', 'DD'), ('AA', 'BB', 'HH', 'CC')),
#  (('AA', 'JJ', 'HH', 'BB'), ('AA', 'EE', 'DD', 'CC')),
#  (('AA', 'BB', 'JJ', 'DD'), ('AA', 'EE', 'HH', 'CC')),
#  (('AA', 'HH', 'JJ', 'EE'), ('AA', 'CC', 'DD', 'BB')),
#  (('AA', 'HH', 'BB', 'CC'), ('AA', 'EE', 'JJ', 'DD')),
#  (('AA', 'BB', 'JJ', 'CC'), ('AA', 'DD', 'HH', 'EE')),
#  (('AA', 'BB', 'JJ', 'HH'), ('AA', 'DD', 'CC', 'EE')),
#  (('AA', 'CC', 'HH', 'DD'), ('AA', 'JJ', 'EE', 'BB')),
#  (('AA', 'CC', 'BB', 'EE'), ('AA', 'JJ', 'DD', 'HH')),
#  (('AA', 'EE', 'DD', 'CC'), ('AA', 'JJ', 'HH', 'BB')),
#  (('AA', 'CC', 'DD', 'JJ'), ('AA', 'BB', 'HH', 'EE')),
#  (('AA', 'JJ', 'HH', 'DD'), ('AA', 'EE', 'CC', 'BB')),
#  (('AA', 'CC', 'JJ', 'HH'), ('AA', 'BB', 'DD', 'EE')),
#  (('AA', 'CC', 'EE', 'DD'), ('AA', 'BB', 'JJ', 'HH')),
#  (('AA', 'EE', 'HH', 'BB'), ('AA', 'DD', 'CC', 'JJ')),
#  (('AA', 'EE', 'CC', 'HH'), ('AA', 'BB', 'DD', 'JJ')),
#  (('AA', 'JJ', 'CC', 'DD'), ('AA', 'HH', 'EE', 'BB')),
#  (('AA', 'DD', 'JJ', 'BB'), ('AA', 'HH', 'EE', 'CC')),
#  (('AA', 'HH', 'JJ', 'BB'), ('AA', 'EE', 'CC', 'DD')),
#  (('AA', 'CC', 'JJ', 'EE'), ('AA', 'HH', 'BB', 'DD')),
#  (('AA', 'DD', 'JJ', 'HH'), ('AA', 'EE', 'BB', 'CC')),
#  (('AA', 'CC', 'EE', 'HH'), ('AA', 'DD', 'BB', 'JJ')),
#  (('AA', 'EE', 'HH', 'CC'), ('AA', 'DD', 'BB', 'JJ')),
#  (('AA', 'HH', 'DD', 'CC'), ('AA', 'BB', 'EE', 'JJ')),
#  (('AA', 'CC', 'BB', 'DD'), ('AA', 'JJ', 'HH', 'EE')),
#  (('AA', 'CC', 'BB', 'HH'), ('AA', 'DD', 'JJ', 'EE')),
#  (('AA', 'HH', 'CC', 'JJ'), ('AA', 'DD', 'EE', 'BB')),
#  (('AA', 'HH', 'CC', 'BB'), ('AA', 'JJ', 'DD', 'EE')),
#  (('AA', 'HH', 'DD', 'CC'), ('AA', 'JJ', 'EE', 'BB')),
#  (('AA', 'HH', 'JJ', 'BB'), ('AA', 'DD', 'EE', 'CC')),
#  (('AA', 'HH', 'JJ', 'CC'), ('AA', 'EE', 'BB', 'DD')),
#  (('AA', 'BB', 'DD', 'JJ'), ('AA', 'HH', 'EE', 'CC')),
#  (('AA', 'DD', 'BB', 'CC'), ('AA', 'JJ', 'EE', 'HH')),
#  (('AA', 'EE', 'BB', 'CC'), ('AA', 'JJ', 'HH', 'DD')),
#  (('AA', 'BB', 'CC', 'HH'), ('AA', 'EE', 'DD', 'JJ')),
#  (('AA', 'JJ', 'EE', 'DD'), ('AA', 'BB', 'CC', 'HH')),
#  (('AA', 'BB', 'DD', 'HH'), ('AA', 'CC', 'EE', 'JJ')),
#  (('AA', 'JJ', 'HH', 'DD'), ('AA', 'BB', 'CC', 'EE')),
#  (('AA', 'BB', 'HH', 'DD'), ('AA', 'EE', 'JJ', 'CC')),
#  (('AA', 'CC', 'BB', 'DD'), ('AA', 'EE', 'HH', 'JJ')),
#  (('AA', 'BB', 'EE', 'DD'), ('AA', 'HH', 'CC', 'JJ')),
#  (('AA', 'CC', 'DD', 'BB'), ('AA', 'EE', 'HH', 'JJ')),
#  (('AA', 'HH', 'EE', 'DD'), ('AA', 'CC', 'BB', 'JJ')),
#  (('AA', 'EE', 'HH', 'JJ'), ('AA', 'CC', 'BB', 'DD')),
#  (('AA', 'JJ', 'EE', 'DD'), ('AA', 'HH', 'CC', 'BB')),
#  (('AA', 'CC', 'EE', 'BB'), ('AA', 'DD', 'HH', 'JJ')),
#  (('AA', 'DD', 'EE', 'JJ'), ('AA', 'BB', 'HH', 'CC')),
#  (('AA', 'BB', 'CC', 'JJ'), ('AA', 'DD', 'HH', 'EE')),
#  (('AA', 'CC', 'JJ', 'EE'), ('AA', 'BB', 'HH', 'DD')),
#  (('AA', 'HH', 'BB', 'JJ'), ('AA', 'DD', 'CC', 'EE')),
#  (('AA', 'EE', 'HH', 'DD'), ('AA', 'CC', 'JJ', 'BB')),
#  (('AA', 'JJ', 'CC', 'BB'), ('AA', 'DD', 'EE', 'HH')),
#  (('AA', 'CC', 'EE', 'BB'), ('AA', 'HH', 'JJ', 'DD')),
#  (('AA', 'HH', 'CC', 'BB'), ('AA', 'EE', 'JJ', 'DD')),
#  (('AA', 'HH', 'DD', 'JJ'), ('AA', 'CC', 'EE', 'BB')),
#  (('AA', 'DD', 'EE', 'HH'), ('AA', 'JJ', 'CC', 'BB')),
#  (('AA', 'JJ', 'BB', 'HH'), ('AA', 'DD', 'CC', 'EE')),
#  (('AA', 'JJ', 'DD', 'BB'), ('AA', 'EE', 'HH', 'CC')),
#  (('AA', 'BB', 'HH', 'EE'), ('AA', 'JJ', 'CC', 'DD')),
#  (('AA', 'HH', 'EE', 'JJ'), ('AA', 'BB', 'DD', 'CC')),
#  (('AA', 'EE', 'HH', 'DD'), ('AA', 'BB', 'CC', 'JJ')),
#  (('AA', 'BB', 'EE', 'CC'), ('AA', 'HH', 'JJ', 'DD')),
#  (('AA', 'HH', 'JJ', 'EE'), ('AA', 'BB', 'CC', 'DD')),
#  (('AA', 'CC', 'JJ', 'BB'), ('AA', 'HH', 'EE', 'DD')),
#  (('AA', 'BB', 'DD', 'CC'), ('AA', 'JJ', 'EE', 'HH')),
#  (('AA', 'DD', 'HH', 'JJ'), ('AA', 'BB', 'EE', 'CC')),
#  (('AA', 'DD', 'CC', 'BB'), ('AA', 'EE', 'JJ', 'HH')),
#  (('AA', 'BB', 'HH', 'JJ'), ('AA', 'EE', 'CC', 'DD')),
#  (('AA', 'BB', 'EE', 'DD'), ('AA', 'CC', 'HH', 'JJ')),
#  (('AA', 'EE', 'BB', 'CC'), ('AA', 'HH', 'DD', 'JJ')),
#  (('AA', 'EE', 'CC', 'HH'), ('AA', 'JJ', 'DD', 'BB')),
#  (('AA', 'BB', 'CC', 'JJ'), ('AA', 'HH', 'DD', 'EE')),
#  (('AA', 'EE', 'CC', 'JJ'), ('AA', 'BB', 'DD', 'HH')),
#  (('AA', 'CC', 'HH', 'DD'), ('AA', 'BB', 'JJ', 'EE')),
#  (('AA', 'CC', 'DD', 'EE'), ('AA', 'JJ', 'HH', 'BB')),
#  (('AA', 'HH', 'DD', 'EE'), ('AA', 'BB', 'JJ', 'CC')),
#  (('AA', 'CC', 'EE', 'HH'), ('AA', 'DD', 'JJ', 'BB')),
#  (('AA', 'EE', 'HH', 'CC'), ('AA', 'DD', 'JJ', 'BB')),
#  (('AA', 'HH', 'CC', 'JJ'), ('AA', 'DD', 'BB', 'EE')),
#  (('AA', 'JJ', 'EE', 'CC'), ('AA', 'BB', 'DD', 'HH')),
#  (('AA', 'CC', 'DD', 'EE'), ('AA', 'HH', 'BB', 'JJ')),
#  (('AA', 'CC', 'EE', 'BB'), ('AA', 'DD', 'JJ', 'HH')),
#  (('AA', 'DD', 'EE', 'BB'), ('AA', 'CC', 'HH', 'JJ')),
#  (('AA', 'EE', 'CC', 'DD'), ('AA', 'JJ', 'HH', 'BB')),
#  (('AA', 'EE', 'JJ', 'DD'), ('AA', 'CC', 'HH', 'BB')),
#  (('AA', 'HH', 'CC', 'EE'), ('AA', 'JJ', 'DD', 'BB')),
#  (('AA', 'DD', 'BB', 'JJ'), ('AA', 'EE', 'HH', 'CC')),
#  (('AA', 'HH', 'BB', 'DD'), ('AA', 'CC', 'EE', 'JJ')),
#  (('AA', 'EE', 'DD', 'CC'), ('AA', 'HH', 'JJ', 'BB')),
#  (('AA', 'JJ', 'HH', 'EE'), ('AA', 'BB', 'DD', 'CC')),
#  (('AA', 'CC', 'EE', 'DD'), ('AA', 'JJ', 'BB', 'HH')),
#  (('AA', 'BB', 'JJ', 'DD'), ('AA', 'EE', 'CC', 'HH')),
#  (('AA', 'EE', 'CC', 'DD'), ('AA', 'HH', 'BB', 'JJ')),
#  (('AA', 'JJ', 'CC', 'DD'), ('AA', 'EE', 'BB', 'HH')),
#  (('AA', 'DD', 'HH', 'JJ'), ('AA', 'CC', 'BB', 'EE')),
#  (('AA', 'HH', 'BB', 'EE'), ('AA', 'DD', 'CC', 'JJ')),
#  (('AA', 'DD', 'HH', 'JJ'), ('AA', 'EE', 'CC', 'BB')),
#  (('AA', 'EE', 'JJ', 'CC'), ('AA', 'HH', 'DD', 'BB')),
#  (('AA', 'CC', 'BB', 'DD'), ('AA', 'JJ', 'EE', 'HH')),
#  (('AA', 'DD', 'CC', 'HH'), ('AA', 'BB', 'EE', 'JJ')),
#  (('AA', 'EE', 'BB', 'DD'), ('AA', 'JJ', 'HH', 'CC')),
#  (('AA', 'DD', 'BB', 'CC'), ('AA', 'HH', 'JJ', 'EE')),
#  (('AA', 'JJ', 'BB', 'DD'), ('AA', 'EE', 'HH', 'CC')),
#  (('AA', 'BB', 'JJ', 'HH'), ('AA', 'CC', 'EE', 'DD')),
#  (('AA', 'HH', 'DD', 'BB'), ('AA', 'CC', 'EE', 'JJ')),
#  (('AA', 'JJ', 'BB', 'HH'), ('AA', 'EE', 'DD', 'CC')),
#  (('AA', 'BB', 'EE', 'DD'), ('AA', 'HH', 'JJ', 'CC')),
#  (('AA', 'DD', 'JJ', 'EE'), ('AA', 'BB', 'HH', 'CC')),
#  (('AA', 'CC', 'EE', 'JJ'), ('AA', 'HH', 'DD', 'BB')),
#  (('AA', 'EE', 'HH', 'JJ'), ('AA', 'DD', 'BB', 'CC')),
#  (('AA', 'CC', 'DD', 'EE'), ('AA', 'BB', 'HH', 'JJ')),
#  (('AA', 'BB', 'JJ', 'CC'), ('AA', 'DD', 'EE', 'HH')),
#  (('AA', 'JJ', 'DD', 'CC'), ('AA', 'HH', 'EE', 'BB')),
#  (('AA', 'DD', 'HH', 'EE'), ('AA', 'JJ', 'CC', 'BB')),
#  (('AA', 'CC', 'EE', 'BB'), ('AA', 'JJ', 'HH', 'DD')),
#  (('AA', 'DD', 'CC', 'JJ'), ('AA', 'HH', 'BB', 'EE')),
#  (('AA', 'DD', 'EE', 'CC'), ('AA', 'BB', 'JJ', 'HH')),
#  (('AA', 'DD', 'HH', 'JJ'), ('AA', 'BB', 'CC', 'EE')),
#  (('AA', 'HH', 'JJ', 'CC'), ('AA', 'BB', 'EE', 'DD')),
#  (('AA', 'CC', 'JJ', 'HH'), ('AA', 'EE', 'BB', 'DD')),
#  (('AA', 'JJ', 'CC', 'EE'), ('AA', 'HH', 'DD', 'BB')),
#  (('AA', 'JJ', 'BB', 'CC'), ('AA', 'EE', 'DD', 'HH')),
#  (('AA', 'CC', 'BB', 'JJ'), ('AA', 'DD', 'EE', 'HH')),
#  (('AA', 'CC', 'JJ', 'EE'), ('AA', 'DD', 'BB', 'HH')),
#  (('AA', 'BB', 'DD', 'EE'), ('AA', 'JJ', 'CC', 'HH')),
#  (('AA', 'JJ', 'CC', 'DD'), ('AA', 'EE', 'HH', 'BB')),
#  (('AA', 'EE', 'BB', 'JJ'), ('AA', 'DD', 'HH', 'CC')),
#  (('AA', 'EE', 'JJ', 'HH'), ('AA', 'BB', 'DD', 'CC')),
#  (('AA', 'DD', 'CC', 'JJ'), ('AA', 'BB', 'EE', 'HH')),
#  (('AA', 'CC', 'BB', 'EE'), ('AA', 'JJ', 'HH', 'DD')),
#  (('AA', 'EE', 'HH', 'JJ'), ('AA', 'CC', 'DD', 'BB')),
#  (('AA', 'CC', 'HH', 'BB'), ('AA', 'DD', 'EE', 'JJ')),
#  (('AA', 'DD', 'CC', 'HH'), ('AA', 'EE', 'BB', 'JJ')),
#  (('AA', 'JJ', 'HH', 'CC'), ('AA', 'EE', 'DD', 'BB')),
#  (('AA', 'CC', 'DD', 'HH'), ('AA', 'EE', 'JJ', 'BB')),
#  (('AA', 'BB', 'EE', 'JJ'), ('AA', 'DD', 'HH', 'CC')),
#  (('AA', 'DD', 'CC', 'JJ'), ('AA', 'BB', 'HH', 'EE')),
#  (('AA', 'BB', 'CC', 'HH'), ('AA', 'JJ', 'DD', 'EE')),
#  (('AA', 'JJ', 'DD', 'BB'), ('AA', 'EE', 'CC', 'HH')),
#  (('AA', 'HH', 'BB', 'JJ'), ('AA', 'CC', 'EE', 'DD')),
#  (('AA', 'JJ', 'DD', 'EE'), ('AA', 'CC', 'BB', 'HH')),
#  (('AA', 'HH', 'BB', 'CC'), ('AA', 'DD', 'EE', 'JJ')),
#  (('AA', 'CC', 'HH', 'DD'), ('AA', 'JJ', 'BB', 'EE')),
#  (('AA', 'HH', 'JJ', 'DD'), ('AA', 'CC', 'BB', 'EE')),
#  (('AA', 'CC', 'DD', 'EE'), ('AA', 'HH', 'JJ', 'BB')),
#  (('AA', 'BB', 'HH', 'CC'), ('AA', 'EE', 'DD', 'JJ')),
#  (('AA', 'DD', 'JJ', 'CC'), ('AA', 'HH', 'EE', 'BB')),
#  (('AA', 'DD', 'HH', 'BB'), ('AA', 'EE', 'JJ', 'CC')),
#  (('AA', 'EE', 'DD', 'HH'), ('AA', 'JJ', 'BB', 'CC')),
#  (('AA', 'CC', 'JJ', 'EE'), ('AA', 'DD', 'HH', 'BB')),
#  (('AA', 'JJ', 'BB', 'HH'), ('AA', 'CC', 'EE', 'DD')),
#  (('AA', 'JJ', 'CC', 'BB'), ('AA', 'DD', 'HH', 'EE')),
#  (('AA', 'BB', 'EE', 'HH'), ('AA', 'JJ', 'CC', 'DD')),
#  (('AA', 'JJ', 'DD', 'HH'), ('AA', 'BB', 'EE', 'CC')),
#  (('AA', 'CC', 'EE', 'BB'), ('AA', 'HH', 'DD', 'JJ')),
#  (('AA', 'EE', 'CC', 'JJ'), ('AA', 'BB', 'HH', 'DD')),
#  (('AA', 'EE', 'CC', 'DD'), ('AA', 'HH', 'JJ', 'BB')),
#  (('AA', 'BB', 'HH', 'EE'), ('AA', 'JJ', 'DD', 'CC')),
#  (('AA', 'JJ', 'CC', 'HH'), ('AA', 'EE', 'DD', 'BB')),
#  (('AA', 'JJ', 'EE', 'DD'), ('AA', 'CC', 'HH', 'BB')),
#  (('AA', 'EE', 'DD', 'JJ'), ('AA', 'CC', 'BB', 'HH')),
#  (('AA', 'DD', 'EE', 'HH'), ('AA', 'CC', 'JJ', 'BB')),
#  (('AA', 'EE', 'DD', 'HH'), ('AA', 'BB', 'JJ', 'CC'))]

# %%
path = [['AA','JJ','BB','CC'],['AA','DD','FF','EE']]
volcano.score_2_paths(path)
# Out:
# 1301

# %%
p = ('AA','DD','BB','JJ','HH','EE','CC')
p in volcano.paths
# Out:
# True

# %%
volcano.score_path(('AA','DD','BB','JJ','HH','EE','CC'), verbose=True)
# Out:
# == Minute 2 ==
# moved 1 times: opened valve DD: at 20 per minute for 28 minutes for a total of 20 per minute
# == Minute 5 ==
# moved 2 times: opened valve BB: at 13 per minute for 25 minutes for a total of 33 per minute
# == Minute 9 ==
# moved 3 times: opened valve JJ: at 21 per minute for 21 minutes for a total of 54 per minute
# == Minute 17 ==
# moved 7 times: opened valve HH: at 22 per minute for 13 minutes for a total of 76 per minute
# == Minute 21 ==
# moved 3 times: opened valve EE: at 3 per minute for 9 minutes for a total of 79 per minute
# == Minute 24 ==
# moved 2 times: opened valve CC: at 2 per minute for 6 minutes for a total of 81 per minute
# 1651

# %%
paths = set()
def grow_2_paths(path1, path2, others, rem1, rem2, show_progress=False):
    if len(others) == 1:
        others = others + ['AA']

    target_options = list(permutations(others,2))
    if show_progress:
        prog = lambda x: tqdm(x)
    else:
        prog = lambda x: x
    for target1,target2 in prog(target_options):

        if rem1>0:
            new_rem1 = rem1 - (volcano.distances[f'{path1[-1]},{target1}']+1)
            if new_rem1>0:
                new_path1 = path1 + [target1]
            else:
                new_path1 = path1
                new_rem1 = rem1                
        else:
            new_path1 = path1
            new_rem1 = rem1

        if rem2>0:
            new_rem2 = rem2 - (volcano.distances[f'{path2[-1]},{target2}']+1)
            if new_rem2>0:
                new_path2 = path2 + [target2]
            else:
                new_path2 = path2
                new_rem2 = rem2                
        else:
            new_path2 = path2
            new_rem2 = rem2
        
        new_others = [i for i in others if i not in (target1,target2)]

        if (new_rem1<=0 and new_rem2<=0) or len(new_others)==0:
            print(f'{path1=}, ')
            paths.add((tuple(new_path1),tuple(new_path2)))
            continue
        else:
            grow_2_paths(new_path1, new_path2, new_others, new_rem1, new_rem2)

grow_2_paths(['AA'],['AA'], volcano.target_valves, 26, 26, show_progress=True)
len(paths)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=210.0), HTML(value='')))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-0bc8e7c8a8a7> in <module>
#      42             grow_2_paths(new_path1, new_path2, new_others, new_rem1, new_rem2)
#      43
# ---> 44 grow_2_paths(['AA'],['AA'], volcano.target_valves, 26, 26, show_progress=True)
#      45 len(paths)
#
# <ipython-input-16-0bc8e7c8a8a7> in grow_2_paths(path1, path2, others, rem1, rem2, show_progress)
#      40             continue
#      41         else:
# ---> 42             grow_2_paths(new_path1, new_path2, new_others, new_rem1, new_rem2)
#      43
#      44 grow_2_paths(['AA'],['AA'], volcano.target_valves, 26, 26, show_progress=True)
#
# <ipython-input-16-0bc8e7c8a8a7> in grow_2_paths(path1, path2, others, rem1, rem2, show_progress)
#      40             continue
#      41         else:
# ---> 42             grow_2_paths(new_path1, new_path2, new_others, new_rem1, new_rem2)
#      43
#      44 grow_2_paths(['AA'],['AA'], volcano.target_valves, 26, 26, show_progress=True)
#
# <ipython-input-16-0bc8e7c8a8a7> in grow_2_paths(path1, path2, others, rem1, rem2, show_progress)
#      40             continue
#      41         else:
# ---> 42             grow_2_paths(new_path1, new_path2, new_others, new_rem1, new_rem2)
#      43
#      44 grow_2_paths(['AA'],['AA'], volcano.target_valves, 26, 26, show_progress=True)
#
# <ipython-input-16-0bc8e7c8a8a7> in grow_2_paths(path1, path2, others, rem1, rem2, show_progress)
#      40             continue
#      41         else:
# ---> 42             grow_2_paths(new_path1, new_path2, new_others, new_rem1, new_rem2)
#      43
#      44 grow_2_paths(['AA'],['AA'], volcano.target_valves, 26, 26, show_progress=True)
#
# <ipython-input-16-0bc8e7c8a8a7> in grow_2_paths(path1, path2, others, rem1, rem2, show_progress)
#      40             continue
#      41         else:
# ---> 42             grow_2_paths(new_path1, new_path2, new_others, new_rem1, new_rem2)
#      43
#      44 grow_2_paths(['AA'],['AA'], volcano.target_valves, 26, 26, show_progress=True)
#
# <ipython-input-16-0bc8e7c8a8a7> in grow_2_paths(path1, path2, others, rem1, rem2, show_progress)
#      40             continue
#      41         else:
# ---> 42             grow_2_paths(new_path1, new_path2, new_others, new_rem1, new_rem2)
#      43
#      44 grow_2_paths(['AA'],['AA'], volcano.target_valves, 26, 26, show_progress=True)
#
# <ipython-input-16-0bc8e7c8a8a7> in grow_2_paths(path1, path2, others, rem1, rem2, show_progress)
#      40             continue
#      41         else:
# ---> 42             grow_2_paths(new_path1, new_path2, new_others, new_rem1, new_rem2)
#      43
#      44 grow_2_paths(['AA'],['AA'], volcano.target_valves, 26, 26, show_progress=True)
#
# <ipython-input-16-0bc8e7c8a8a7> in grow_2_paths(path1, path2, others, rem1, rem2, show_progress)
#      37         if (new_rem1<=0 and new_rem2<=0) or len(new_others)==0:
#      38             paths.add((tuple(new_path1),tuple(new_path2)))
# ---> 39             print(paths[-1])
#      40             continue
#      41         else:
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# **--- Part Two ---**

# %%
list(permutations(volcano.target_valves,2))
# Out:
# [('BB', 'CC'),
#  ('BB', 'DD'),
#  ('BB', 'EE'),
#  ('BB', 'HH'),
#  ('BB', 'JJ'),
#  ('CC', 'BB'),
#  ('CC', 'DD'),
#  ('CC', 'EE'),
#  ('CC', 'HH'),
#  ('CC', 'JJ'),
#  ('DD', 'BB'),
#  ('DD', 'CC'),
#  ('DD', 'EE'),
#  ('DD', 'HH'),
#  ('DD', 'JJ'),
#  ('EE', 'BB'),
#  ('EE', 'CC'),
#  ('EE', 'DD'),
#  ('EE', 'HH'),
#  ('EE', 'JJ'),
#  ('HH', 'BB'),
#  ('HH', 'CC'),
#  ('HH', 'DD'),
#  ('HH', 'EE'),
#  ('HH', 'JJ'),
#  ('JJ', 'BB'),
#  ('JJ', 'CC'),
#  ('JJ', 'DD'),
#  ('JJ', 'EE'),
#  ('JJ', 'HH')]
